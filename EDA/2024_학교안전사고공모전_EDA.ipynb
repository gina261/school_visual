# %% [markdown]
# <a href="https://colab.research.google.com/github/gina261/school_visual/blob/main/2024_%ED%95%99%EA%B5%90%EC%95%88%EC%A0%84%EC%82%AC%EA%B3%A0%EA%B3%B5%EB%AA%A8%EC%A0%84_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

# %%
#!sudo apt-get install -y fonts-nanum

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.rc('font', family='NanumGothic') # 폰트 설정
plt.rc('axes', unicode_minus=False) # 유니코드에서 음수 부호 설정

# 차트 스타일 설정
sns.set(font="NanumGothic", rc={"axes.unicode_minus":False}, style='darkgrid')
plt.rc("figure", figsize=(10,8))

warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2019-2023 학교안전사고 데이터
edu2019 = pd.read_csv("/content/drive/MyDrive/2024학교안전/2019학교안전사고데이터.csv", encoding = "CP949")
edu2020 = pd.read_csv("/content/drive/MyDrive/2024학교안전/2020학교안전사고데이터.csv", encoding = "CP949")
edu2021 = pd.read_csv("/content/drive/MyDrive/2024학교안전/2021학교안전사고데이터.csv", encoding = "CP949")
edu2022 = pd.read_csv("/content/drive/MyDrive/2024학교안전/2022학교안전사고데이터.csv", encoding = "CP949")
edu2023 = pd.read_csv("/content/drive/MyDrive/2024학교안전/2023학교안전사고데이터.csv", encoding = "CP949")

# 교육부 학교안전교육 전문강사 인력풀 현황
pro_edu = pd.read_csv("/content/drive/MyDrive/2024학교안전/교육부_학교안전교육 전문강사 인력풀 현황_20240423.csv", encoding = "CP949")

# 한국청소년활동진흥원 청소년 생활(학교) 사고 통계
school_part = pd.read_csv("/content/drive/MyDrive/2024학교안전/학교생활별(부위별) 안전사고 현황 데이터.csv", encoding = "CP949")
school_time = pd.read_csv("/content/drive/MyDrive/2024학교안전/학교생활별(시간별) 안전사고 현황 데이터.csv", encoding = "CP949")
school_place = pd.read_csv("/content/drive/MyDrive/2024학교안전/학교생활별(장소별) 안전사고 현황 데이터.csv", encoding = "CP949")
school_shape = pd.read_csv("/content/drive/MyDrive/2024학교안전/학교생활별(형태별) 안전사고 현황 데이터.csv", encoding = "CP949")

# %% [markdown]
# #### **2019-2023 학교안전사고 데이터**

# %%
edu2019 = edu2019[['구분', '학교급', '지역', '교육청', '설립유형', '사고자구분', '사고자성별', '사고자학년', '사고발생일',
       '사고발생요일', '사고발생시각', '사고시간', '사고장소', '사고부위', '사고형태', '사고당시활동', '사고매개물']]
edu2020 = edu2020[['구분', '학교급', '지역', '교육청', '설립유형', '사고자구분', '사고자성별', '사고자학년', '사고발생일',
       '사고발생요일', '사고발생시각', '사고시간', '사고장소', '사고부위', '사고형태', '사고당시활동', '사고매개물']]
edu2021 = edu2021[['구분', '학교급', '지역', '교육청', '설립유형', '사고자구분', '사고자성별', '사고자학년', '사고발생일',
       '사고발생요일', '사고발생시각', '사고시간', '사고장소', '사고부위', '사고형태', '사고당시활동', '사고매개물']]
edu2022 = edu2022[['구분', '학교급', '지역', '교육청', '설립유형', '사고자구분', '사고자성별', '사고자학년', '사고발생일',
       '사고발생요일', '사고발생시각', '사고시간', '사고장소', '사고부위', '사고형태', '사고당시활동', '사고매개물']]
edu2023 = edu2023[['구분', '학교급', '지역', '교육청', '설립유형', '사고자구분', '사고자성별', '사고자학년', '사고발생일',
       '사고발생요일', '사고발생시각', '사고시간', '사고장소', '사고부위', '사고형태', '사고당시활동', '매개물']] # 2023년에는 '사고매개물'이 아닌 그냥 '매개물'로 적혀있음

# %% [markdown]
# #####1. 2019 학교안전사고 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
edu2019.head(1)
# Out:
#          구분   학교급  지역     교육청 설립유형 사고자구분 사고자성별 사고자학년       사고발생일 사고발생요일  \
# 0  A0000001  기타학교  경기  경기도교육청   사립  일반학생     여   2학년  2018-12-28      금
#
#   사고발생시각  사고시간 사고장소 사고부위     사고형태 사고당시활동               사고매개물
# 0  13:10  수업시간   교실    손  물리적힘 노출   실험실습  날카로운 물건(칼/가위/송곳 등)

# %%
edu2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138784 entries, 0 to 138783
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   구분      138784 non-null  object
#  1   학교급     138784 non-null  object
#  2   지역      138784 non-null  object
#  3   교육청     138784 non-null  object
#  4   설립유형    138784 non-null  object
#  5   사고자구분   138783 non-null  object
#  6   사고자성별   138784 non-null  object
#  7   사고자학년   138193 non-null  object
#  8   사고발생일   138784 non-null  object
#  9   사고발생요일  138784 non-null  object
#  10  사고발생시각  138784 non-null  object
#  11  사고시간    138784 non-null  object
#  12  사고장소    138784 non-null  object
#  13  사고부위    138784 non-null  object
#  14  사고형태    138784 non-null  object
#  15  사고당시활동  138784 non-null  object
#  16  사고매개물   138784 non-null  object
# dtypes: object(17)
# memory usage: 18.0+ MB

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '학교급' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
school_levels = edu2019['학교급'].value_counts()
school_labels = school_levels.index.tolist()
school_values = school_levels.values.tolist()

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2019['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

# '지역' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
region_levels = edu2019['지역'].value_counts()
region_labels = region_levels.index.tolist()
region_values = region_levels.values.tolist()

# '설립유형' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
establish_levels = edu2019['설립유형'].value_counts()
establish_labels = establish_levels.index.tolist()
establish_values = establish_levels.values.tolist()

# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=school_labels, values=school_values, hole=.3, title="학교급"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=region_labels, values=region_values, hole=.3, title="지역"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=establish_labels, values=establish_values, hole=.3, title="설립유형"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="학교 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2019['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

data = {
    '교육청': edu_labels,
    'count': edu_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="교육청", y="count", title="사건 수 상위 10개 교육청")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고자구분' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
acc_levels = edu2019['사고자구분'].value_counts()
acc_labels = acc_levels.index.tolist()
acc_values = acc_levels.values.tolist()

# '사고자성별' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sex_levels = edu2019['사고자성별'].value_counts()
sex_labels = sex_levels.index.tolist()
sex_values = sex_levels.values.tolist()

# '사고자학년' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
class_levels = edu2019['사고자학년'].value_counts()
class_labels = class_levels.index.tolist()
class_values = class_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=acc_labels, values=acc_values, hole=.3, title="사고자구분"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sex_labels, values=sex_values, hole=.3, title="사고자성별"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=class_labels, values=class_values, hole=.3, title="사고자학년"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고자 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 사고 발생일에서 '월'의 정보만 가진 '사고발생월'열 생성
edu2019['사고발생일'] = pd.to_datetime(edu2019['사고발생일'])
edu2019['사고발생월'] = edu2019['사고발생일'].dt.month

# '사고발생시각' 열에서 시간 정보만 추출하여 '사고발생시간' 열 생성
edu2019['사고발생시간'] = edu2019['사고발생시각'].str.split(':').str[0]
edu2019.head(1)
# Out:
#          구분   학교급  지역     교육청 설립유형 사고자구분 사고자성별 사고자학년      사고발생일 사고발생요일 사고발생시각  \
# 0  A0000001  기타학교  경기  경기도교육청   사립  일반학생     여   2학년 2018-12-28      금  13:10
#
#    사고시간 사고장소 사고부위     사고형태 사고당시활동               사고매개물  사고발생월 사고발생시간
# 0  수업시간   교실    손  물리적힘 노출   실험실습  날카로운 물건(칼/가위/송곳 등)     12     13

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고발생월' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
month_levels = edu2019['사고발생월'].value_counts()
month_labels = month_levels.index.tolist()
month_values = month_levels.values.tolist()

# '사고발생시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
time_levels = edu2019['사고발생시간'].value_counts()
time_labels = time_levels.index.tolist()
time_values = time_levels.values.tolist()

# '사고발생요일' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
day_levels = edu2019['사고발생요일'].value_counts()
day_labels = day_levels.index.tolist()
day_values = day_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=month_labels, values=month_values, hole=.3, title="사고발생월"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=time_labels, values=time_values, hole=.3, title="사고발생시간"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=day_labels, values=day_values, hole=.3, title="사고발생요일"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고발생 시간 관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sche_levels = edu2019['사고시간'].value_counts()
sche_labels = sche_levels.index.tolist()
sche_values = sche_levels.values.tolist()

# '사고당시활동' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
activity_levels = edu2019['사고당시활동'].value_counts()
act_labels = activity_levels.index.tolist()
act_values = activity_levels.values.tolist()

# 서브플롯 생성 (1행 2열의 레이아웃)
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sche_labels, values=sche_values, hole=.3, title="사고시간"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=act_labels, values=act_values, hole=.3, title="사고당시활동"), 1, 2)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 활동 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고장소' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
spot_levels = edu2019['사고장소'].value_counts()
spot_labels = spot_levels.index.tolist()
spot_values = spot_levels.values.tolist()

# '사고부위' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
part_levels = edu2019['사고부위'].value_counts()
part_labels = part_levels.index.tolist()
part_values = part_levels.values.tolist()

# '사고형태' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
form_levels = edu2019['사고형태'].value_counts()
form_labels = form_levels.index.tolist()
form_values = form_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=spot_labels, values=spot_values, hole=.3, title="사고장소"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=part_labels, values=part_values, hole=.3, title="사고부위"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=form_labels, values=form_values, hole=.3, title="사고형태"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '사고매개물' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
me_levels = edu2019['사고매개물'].value_counts()
me_labels = me_levels.index.tolist()
me_values = me_levels.values.tolist()

data = {
    '사고매개물': me_labels,
    'count': me_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="사고매개물", y="count", title="사고관련 매개물")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####2. 2020 학교안전사고 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
edu2020.head(1)
# Out:
#          구분   학교급  지역      교육청 설립유형 사고자구분 사고자성별 사고자학년       사고발생일 사고발생요일  \
# 0  B0000001  초등학교  경기  용인교육지원청   공립  일반학생     남   5학년  2019-06-27      목
#
#   사고발생시각  사고시간 사고장소 사고부위     사고형태 사고당시활동                           사고매개물
# 0  13:30  점심시간  운동장    발  낙상-미끄러짐   구기운동  운동(놀이)용 장비/기구(공/운동기구/운동장 기구 등)

# %%
edu2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41940 entries, 0 to 41939
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      41940 non-null  object
#  1   학교급     41940 non-null  object
#  2   지역      41940 non-null  object
#  3   교육청     41940 non-null  object
#  4   설립유형    41940 non-null  object
#  5   사고자구분   41940 non-null  object
#  6   사고자성별   41940 non-null  object
#  7   사고자학년   41832 non-null  object
#  8   사고발생일   41940 non-null  object
#  9   사고발생요일  41940 non-null  object
#  10  사고발생시각  41940 non-null  object
#  11  사고시간    41940 non-null  object
#  12  사고장소    41940 non-null  object
#  13  사고부위    41940 non-null  object
#  14  사고형태    41940 non-null  object
#  15  사고당시활동  41940 non-null  object
#  16  사고매개물   41940 non-null  object
# dtypes: object(17)
# memory usage: 5.4+ MB

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '학교급' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
school_levels = edu2020['학교급'].value_counts()
school_labels = school_levels.index.tolist()
school_values = school_levels.values.tolist()

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2020['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

# '지역' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
region_levels = edu2020['지역'].value_counts()
region_labels = region_levels.index.tolist()
region_values = region_levels.values.tolist()

# '설립유형' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
establish_levels = edu2020['설립유형'].value_counts()
establish_labels = establish_levels.index.tolist()
establish_values = establish_levels.values.tolist()

# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=school_labels, values=school_values, hole=.3, title="학교급"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=region_labels, values=region_values, hole=.3, title="지역"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=establish_labels, values=establish_values, hole=.3, title="설립유형"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="학교 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2020['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

data = {
    '교육청': edu_labels,
    'count': edu_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="교육청", y="count", title="사건 수 상위 10개 교육청")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고자구분' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
acc_levels = edu2020['사고자구분'].value_counts()
acc_labels = acc_levels.index.tolist()
acc_values = acc_levels.values.tolist()

# '사고자성별' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sex_levels = edu2020['사고자성별'].value_counts()
sex_labels = sex_levels.index.tolist()
sex_values = sex_levels.values.tolist()

# '사고자학년' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
class_levels = edu2020['사고자학년'].value_counts()
class_labels = class_levels.index.tolist()
class_values = class_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=acc_labels, values=acc_values, hole=.3, title="사고자구분"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sex_labels, values=sex_values, hole=.3, title="사고자성별"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=class_labels, values=class_values, hole=.3, title="사고자학년"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고자 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 사고 발생일에서 '월'의 정보만 가진 '사고발생월'열 생성
edu2020['사고발생일'] = pd.to_datetime(edu2020['사고발생일'])
edu2020['사고발생월'] = edu2020['사고발생일'].dt.month

# '사고발생시각' 열에서 시간 정보만 추출하여 '사고발생시간' 열 생성
edu2020['사고발생시간'] = edu2020['사고발생시각'].str.split(':').str[0]
edu2020.head(1)
# Out:
#          구분   학교급  지역      교육청 설립유형 사고자구분 사고자성별 사고자학년      사고발생일 사고발생요일  \
# 0  B0000001  초등학교  경기  용인교육지원청   공립  일반학생     남   5학년 2019-06-27      목
#
#   사고발생시각  사고시간 사고장소 사고부위     사고형태 사고당시활동                           사고매개물  \
# 0  13:30  점심시간  운동장    발  낙상-미끄러짐   구기운동  운동(놀이)용 장비/기구(공/운동기구/운동장 기구 등)
#
#    사고발생월 사고발생시간
# 0      6     13

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고발생월' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
month_levels = edu2020['사고발생월'].value_counts()
month_labels = month_levels.index.tolist()
month_values = month_levels.values.tolist()

# '사고발생시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
time_levels = edu2020['사고발생시간'].value_counts()
time_labels = time_levels.index.tolist()
time_values = time_levels.values.tolist()

# '사고발생요일' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
day_levels = edu2020['사고발생요일'].value_counts()
day_labels = day_levels.index.tolist()
day_values = day_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=month_labels, values=month_values, hole=.3, title="사고발생월"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=time_labels, values=time_values, hole=.3, title="사고발생시간"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=day_labels, values=day_values, hole=.3, title="사고발생요일"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고발생 시간 관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sche_levels = edu2020['사고시간'].value_counts()
sche_labels = sche_levels.index.tolist()
sche_values = sche_levels.values.tolist()

# '사고당시활동' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
activity_levels = edu2020['사고당시활동'].value_counts()
act_labels = activity_levels.index.tolist()
act_values = activity_levels.values.tolist()

# 서브플롯 생성 (1행 2열의 레이아웃)
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sche_labels, values=sche_values, hole=.3, title="사고시간"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=act_labels, values=act_values, hole=.3, title="사고당시활동"), 1, 2)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 활동 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고장소' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
spot_levels = edu2020['사고장소'].value_counts()
spot_labels = spot_levels.index.tolist()
spot_values = spot_levels.values.tolist()

# '사고부위' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
part_levels = edu2020['사고부위'].value_counts()
part_labels = part_levels.index.tolist()
part_values = part_levels.values.tolist()

# '사고형태' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
form_levels = edu2020['사고형태'].value_counts()
form_labels = form_levels.index.tolist()
form_values = form_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=spot_labels, values=spot_values, hole=.3, title="사고장소"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=part_labels, values=part_values, hole=.3, title="사고부위"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=form_labels, values=form_values, hole=.3, title="사고형태"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '사고매개물' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
me_levels = edu2020['사고매개물'].value_counts()
me_labels = me_levels.index.tolist()
me_values = me_levels.values.tolist()

data = {
    '사고매개물': me_labels,
    'count': me_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="사고매개물", y="count", title="사고관련 매개물")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####3. 2021 학교안전사고 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
edu2021.head(1)
# Out:
#          구분   학교급  지역      교육청 설립유형 사고자구분 사고자성별 사고자학년       사고발생일 사고발생요일  \
# 0  C0000001  초등학교  경기  성남교육지원청   공립  일반학생     남   6학년  2020-11-20      금
#
#   사고발생시각  사고시간  사고장소 사고부위     사고형태 사고당시활동                           사고매개물
# 0  09:20  체육수업  부속시설    발  낙상-미끄러짐   구기운동  운동(놀이)용 장비/기구(공/운동기구/운동장 기구 등)

# %%
edu2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93147 entries, 0 to 93146
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      93147 non-null  object
#  1   학교급     93147 non-null  object
#  2   지역      93147 non-null  object
#  3   교육청     93147 non-null  object
#  4   설립유형    93147 non-null  object
#  5   사고자구분   93147 non-null  object
#  6   사고자성별   93147 non-null  object
#  7   사고자학년   92947 non-null  object
#  8   사고발생일   93147 non-null  object
#  9   사고발생요일  93147 non-null  object
#  10  사고발생시각  93147 non-null  object
#  11  사고시간    93147 non-null  object
#  12  사고장소    93147 non-null  object
#  13  사고부위    93147 non-null  object
#  14  사고형태    93147 non-null  object
#  15  사고당시활동  93147 non-null  object
#  16  사고매개물   93147 non-null  object
# dtypes: object(17)
# memory usage: 12.1+ MB

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '학교급' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
school_levels = edu2021['학교급'].value_counts()
school_labels = school_levels.index.tolist()
school_values = school_levels.values.tolist()

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2021['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

# '지역' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
region_levels = edu2021['지역'].value_counts()
region_labels = region_levels.index.tolist()
region_values = region_levels.values.tolist()

# '설립유형' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
establish_levels = edu2021['설립유형'].value_counts()
establish_labels = establish_levels.index.tolist()
establish_values = establish_levels.values.tolist()

# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=school_labels, values=school_values, hole=.3, title="학교급"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=region_labels, values=region_values, hole=.3, title="지역"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=establish_labels, values=establish_values, hole=.3, title="설립유형"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="학교 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2021['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

data = {
    '교육청': edu_labels,
    'count': edu_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="교육청", y="count", title="사건 수 상위 10개 교육청")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고자구분' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
acc_levels = edu2021['사고자구분'].value_counts()
acc_labels = acc_levels.index.tolist()
acc_values = acc_levels.values.tolist()

# '사고자성별' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sex_levels = edu2021['사고자성별'].value_counts()
sex_labels = sex_levels.index.tolist()
sex_values = sex_levels.values.tolist()

# '사고자학년' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
class_levels = edu2021['사고자학년'].value_counts()
class_labels = class_levels.index.tolist()
class_values = class_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=acc_labels, values=acc_values, hole=.3, title="사고자구분"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sex_labels, values=sex_values, hole=.3, title="사고자성별"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=class_labels, values=class_values, hole=.3, title="사고자학년"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고자 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 사고 발생일에서 '월'의 정보만 가진 '사고발생월'열 생성
edu2021['사고발생일'] = pd.to_datetime(edu2021['사고발생일'])
edu2021['사고발생월'] = edu2021['사고발생일'].dt.month

# '사고발생시각' 열에서 시간 정보만 추출하여 '사고발생시간' 열 생성
edu2021['사고발생시간'] = edu2021['사고발생시각'].str.split(':').str[0]
edu2021.head(1)
# Out:
#          구분   학교급  지역      교육청 설립유형 사고자구분 사고자성별 사고자학년      사고발생일 사고발생요일  \
# 0  C0000001  초등학교  경기  성남교육지원청   공립  일반학생     남   6학년 2020-11-20      금
#
#   사고발생시각  사고시간  사고장소 사고부위     사고형태 사고당시활동                           사고매개물  \
# 0  09:20  체육수업  부속시설    발  낙상-미끄러짐   구기운동  운동(놀이)용 장비/기구(공/운동기구/운동장 기구 등)
#
#    사고발생월 사고발생시간
# 0     11     09

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고발생월' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
month_levels = edu2021['사고발생월'].value_counts()
month_labels = month_levels.index.tolist()
month_values = month_levels.values.tolist()

# '사고발생시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
time_levels = edu2021['사고발생시간'].value_counts()
time_labels = time_levels.index.tolist()
time_values = time_levels.values.tolist()

# '사고발생요일' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
day_levels = edu2021['사고발생요일'].value_counts()
day_labels = day_levels.index.tolist()
day_values = day_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=month_labels, values=month_values, hole=.3, title="사고발생월"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=time_labels, values=time_values, hole=.3, title="사고발생시간"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=day_labels, values=day_values, hole=.3, title="사고발생요일"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고발생 시간 관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sche_levels = edu2021['사고시간'].value_counts()
sche_labels = sche_levels.index.tolist()
sche_values = sche_levels.values.tolist()

# '사고당시활동' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
activity_levels = edu2021['사고당시활동'].value_counts()
act_labels = activity_levels.index.tolist()
act_values = activity_levels.values.tolist()

# 서브플롯 생성 (1행 2열의 레이아웃)
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sche_labels, values=sche_values, hole=.3, title="사고시간"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=act_labels, values=act_values, hole=.3, title="사고당시활동"), 1, 2)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 활동 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고장소' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
spot_levels = edu2021['사고장소'].value_counts()
spot_labels = spot_levels.index.tolist()
spot_values = spot_levels.values.tolist()

# '사고부위' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
part_levels = edu2021['사고부위'].value_counts()
part_labels = part_levels.index.tolist()
part_values = part_levels.values.tolist()

# '사고형태' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
form_levels = edu2021['사고형태'].value_counts()
form_labels = form_levels.index.tolist()
form_values = form_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=spot_labels, values=spot_values, hole=.3, title="사고장소"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=part_labels, values=part_values, hole=.3, title="사고부위"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=form_labels, values=form_values, hole=.3, title="사고형태"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '사고매개물' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
me_levels = edu2021['사고매개물'].value_counts()
me_labels = me_levels.index.tolist()
me_values = me_levels.values.tolist()

data = {
    '사고매개물': me_labels,
    'count': me_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="사고매개물", y="count", title="사고관련 매개물")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####4. 2022 학교안전사고 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
edu2022.head(1)
# Out:
#          구분   학교급  지역      교육청 설립유형 사고자구분 사고자성별 사고자학년       사고발생일 사고발생요일  \
# 0  D0000001  초등학교  경기  수원교육지원청   공립  일반학생     남   6학년  2021-12-13      월
#
#   사고발생시각  사고시간  사고장소 사고부위    사고형태 사고당시활동            사고매개물
# 0  09:20  체육수업  부속시설   다리  낙상-넘어짐   기타운동  건물(문/창문/바닥/벽 등)

# %%
edu2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149339 entries, 0 to 149338
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   구분      149339 non-null  object
#  1   학교급     149339 non-null  object
#  2   지역      149339 non-null  object
#  3   교육청     149339 non-null  object
#  4   설립유형    149339 non-null  object
#  5   사고자구분   149339 non-null  object
#  6   사고자성별   149339 non-null  object
#  7   사고자학년   149078 non-null  object
#  8   사고발생일   149339 non-null  object
#  9   사고발생요일  149339 non-null  object
#  10  사고발생시각  149339 non-null  object
#  11  사고시간    149339 non-null  object
#  12  사고장소    149339 non-null  object
#  13  사고부위    149339 non-null  object
#  14  사고형태    149339 non-null  object
#  15  사고당시활동  149339 non-null  object
#  16  사고매개물   149339 non-null  object
# dtypes: object(17)
# memory usage: 19.4+ MB

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '학교급' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
school_levels = edu2022['학교급'].value_counts()
school_labels = school_levels.index.tolist()
school_values = school_levels.values.tolist()

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2022['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

# '지역' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
region_levels = edu2022['지역'].value_counts()
region_labels = region_levels.index.tolist()
region_values = region_levels.values.tolist()

# '설립유형' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
establish_levels = edu2022['설립유형'].value_counts()
establish_labels = establish_levels.index.tolist()
establish_values = establish_levels.values.tolist()

# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=school_labels, values=school_values, hole=.3, title="학교급"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=region_labels, values=region_values, hole=.3, title="지역"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=establish_labels, values=establish_values, hole=.3, title="설립유형"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="학교 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2022['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

data = {
    '교육청': edu_labels,
    'count': edu_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="교육청", y="count", title="사건 수 상위 10개 교육청")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고자구분' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
acc_levels = edu2022['사고자구분'].value_counts()
acc_labels = acc_levels.index.tolist()
acc_values = acc_levels.values.tolist()

# '사고자성별' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sex_levels = edu2022['사고자성별'].value_counts()
sex_labels = sex_levels.index.tolist()
sex_values = sex_levels.values.tolist()

# '사고자학년' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
class_levels = edu2022['사고자학년'].value_counts()
class_labels = class_levels.index.tolist()
class_values = class_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=acc_labels, values=acc_values, hole=.3, title="사고자구분"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sex_labels, values=sex_values, hole=.3, title="사고자성별"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=class_labels, values=class_values, hole=.3, title="사고자학년"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고자 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 사고 발생일에서 '월'의 정보만 가진 '사고발생월'열 생성
edu2022['사고발생일'] = pd.to_datetime(edu2022['사고발생일'])
edu2022['사고발생월'] = edu2022['사고발생일'].dt.month

# '사고발생시각' 열에서 시간 정보만 추출하여 '사고발생시간' 열 생성
edu2022['사고발생시간'] = edu2022['사고발생시각'].str.split(':').str[0]
edu2022.head(1)
# Out:
#          구분   학교급  지역      교육청 설립유형 사고자구분 사고자성별 사고자학년      사고발생일 사고발생요일  \
# 0  D0000001  초등학교  경기  수원교육지원청   공립  일반학생     남   6학년 2021-12-13      월
#
#   사고발생시각  사고시간  사고장소 사고부위    사고형태 사고당시활동            사고매개물  사고발생월 사고발생시간
# 0  09:20  체육수업  부속시설   다리  낙상-넘어짐   기타운동  건물(문/창문/바닥/벽 등)     12     09

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고발생월' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
month_levels = edu2022['사고발생월'].value_counts()
month_labels = month_levels.index.tolist()
month_values = month_levels.values.tolist()

# '사고발생시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
time_levels = edu2022['사고발생시간'].value_counts()
time_labels = time_levels.index.tolist()
time_values = time_levels.values.tolist()

# '사고발생요일' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
day_levels = edu2022['사고발생요일'].value_counts()
day_labels = day_levels.index.tolist()
day_values = day_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=month_labels, values=month_values, hole=.3, title="사고발생월"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=time_labels, values=time_values, hole=.3, title="사고발생시간"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=day_labels, values=day_values, hole=.3, title="사고발생요일"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고발생 시간 관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sche_levels = edu2022['사고시간'].value_counts()
sche_labels = sche_levels.index.tolist()
sche_values = sche_levels.values.tolist()

# '사고당시활동' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
activity_levels = edu2022['사고당시활동'].value_counts()
act_labels = activity_levels.index.tolist()
act_values = activity_levels.values.tolist()

# 서브플롯 생성 (1행 2열의 레이아웃)
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sche_labels, values=sche_values, hole=.3, title="사고시간"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=act_labels, values=act_values, hole=.3, title="사고당시활동"), 1, 2)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 활동 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고장소' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
spot_levels = edu2022['사고장소'].value_counts()
spot_labels = spot_levels.index.tolist()
spot_values = spot_levels.values.tolist()

# '사고부위' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
part_levels = edu2022['사고부위'].value_counts()
part_labels = part_levels.index.tolist()
part_values = part_levels.values.tolist()

# '사고형태' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
form_levels = edu2022['사고형태'].value_counts()
form_labels = form_levels.index.tolist()
form_values = form_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=spot_labels, values=spot_values, hole=.3, title="사고장소"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=part_labels, values=part_values, hole=.3, title="사고부위"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=form_labels, values=form_values, hole=.3, title="사고형태"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '사고매개물' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
me_levels = edu2022['사고매개물'].value_counts()
me_labels = me_levels.index.tolist()
me_values = me_levels.values.tolist()

data = {
    '사고매개물': me_labels,
    'count': me_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="사고매개물", y="count", title="사고관련 매개물")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####5. 2023 학교안전사고 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
edu2023.head(1)
# Out:
#          구분   학교급  지역       교육청 설립유형 사고자구분 사고자성별 사고자학년       사고발생일 사고발생요일  \
# 0  E0000001  초등학교  제주  제주시교육지원청   공립  일반학생     남   6학년  2022-10-28      금
#
#   사고발생시각  사고시간 사고장소 사고부위     사고형태 사고당시활동                             매개물
# 0  12:40  식사시간  운동장    손  물리적힘 노출   구기운동  운동(놀이)용 장비/기구(공/운동기구/운동장 기구 등)

# %%
edu2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193177 entries, 0 to 193176
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   구분      193177 non-null  object
#  1   학교급     193177 non-null  object
#  2   지역      193177 non-null  object
#  3   교육청     193177 non-null  object
#  4   설립유형    193177 non-null  object
#  5   사고자구분   193177 non-null  object
#  6   사고자성별   193177 non-null  object
#  7   사고자학년   192727 non-null  object
#  8   사고발생일   193177 non-null  object
#  9   사고발생요일  193177 non-null  object
#  10  사고발생시각  193177 non-null  object
#  11  사고시간    193177 non-null  object
#  12  사고장소    193177 non-null  object
#  13  사고부위    193177 non-null  object
#  14  사고형태    193177 non-null  object
#  15  사고당시활동  193177 non-null  object
#  16  매개물     193177 non-null  object
# dtypes: object(17)
# memory usage: 25.1+ MB

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '학교급' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
school_levels = edu2023['학교급'].value_counts()
school_labels = school_levels.index.tolist()
school_values = school_levels.values.tolist()

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2023['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

# '지역' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
region_levels = edu2023['지역'].value_counts()
region_labels = region_levels.index.tolist()
region_values = region_levels.values.tolist()

# '설립유형' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
establish_levels = edu2023['설립유형'].value_counts()
establish_labels = establish_levels.index.tolist()
establish_values = establish_levels.values.tolist()

# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=school_labels, values=school_values, hole=.3, title="학교급"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=region_labels, values=region_values, hole=.3, title="지역"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=establish_labels, values=establish_values, hole=.3, title="설립유형"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="학교 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '교육청' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
edu_levels = edu2023['교육청'].value_counts()
edu_labels = edu_levels.index.tolist()
edu_values = edu_levels.values.tolist()

data = {
    '교육청': edu_labels,
    'count': edu_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="교육청", y="count", title="사건 수 상위 10개 교육청")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고자구분' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
acc_levels = edu2023['사고자구분'].value_counts()
acc_labels = acc_levels.index.tolist()
acc_values = acc_levels.values.tolist()

# '사고자성별' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sex_levels = edu2023['사고자성별'].value_counts()
sex_labels = sex_levels.index.tolist()
sex_values = sex_levels.values.tolist()

# '사고자학년' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
class_levels = edu2023['사고자학년'].value_counts()
class_labels = class_levels.index.tolist()
class_values = class_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=acc_labels, values=acc_values, hole=.3, title="사고자구분"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sex_labels, values=sex_values, hole=.3, title="사고자성별"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=class_labels, values=class_values, hole=.3, title="사고자학년"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고자 관련 기본 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 사고 발생일에서 '월'의 정보만 가진 '사고발생월'열 생성
edu2023['사고발생일'] = pd.to_datetime(edu2023['사고발생일'])
edu2023['사고발생월'] = edu2023['사고발생일'].dt.month

# '사고발생시각' 열에서 시간 정보만 추출하여 '사고발생시간' 열 생성
edu2023['사고발생시간'] = edu2023['사고발생시각'].str.split(':').str[0]
edu2023.head(1)
# Out:
#          구분   학교급  지역       교육청 설립유형 사고자구분 사고자성별 사고자학년      사고발생일 사고발생요일  \
# 0  E0000001  초등학교  제주  제주시교육지원청   공립  일반학생     남   6학년 2022-10-28      금
#
#   사고발생시각  사고시간 사고장소 사고부위     사고형태 사고당시활동                             매개물  \
# 0  12:40  식사시간  운동장    손  물리적힘 노출   구기운동  운동(놀이)용 장비/기구(공/운동기구/운동장 기구 등)
#
#    사고발생월 사고발생시간
# 0     10     12

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고발생월' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
month_levels = edu2023['사고발생월'].value_counts()
month_labels = month_levels.index.tolist()
month_values = month_levels.values.tolist()

# '사고발생시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
time_levels = edu2023['사고발생시간'].value_counts()
time_labels = time_levels.index.tolist()
time_values = time_levels.values.tolist()

# '사고발생요일' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
day_levels = edu2023['사고발생요일'].value_counts()
day_labels = day_levels.index.tolist()
day_values = day_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=month_labels, values=month_values, hole=.3, title="사고발생월"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=time_labels, values=time_values, hole=.3, title="사고발생시간"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=day_labels, values=day_values, hole=.3, title="사고발생요일"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고발생 시간 관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고시간' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
sche_levels = edu2023['사고시간'].value_counts()
sche_labels = sche_levels.index.tolist()
sche_values = sche_levels.values.tolist()

# '사고당시활동' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
activity_levels = edu2023['사고당시활동'].value_counts()
act_labels = activity_levels.index.tolist()
act_values = activity_levels.values.tolist()

# 서브플롯 생성 (1행 2열의 레이아웃)
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=sche_labels, values=sche_values, hole=.3, title="사고시간"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=act_labels, values=act_values, hole=.3, title="사고당시활동"), 1, 2)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 활동 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# '사고장소' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
spot_levels = edu2023['사고장소'].value_counts()
spot_labels = spot_levels.index.tolist()
spot_values = spot_levels.values.tolist()

# '사고부위' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
part_levels = edu2023['사고부위'].value_counts()
part_labels = part_levels.index.tolist()
part_values = part_levels.values.tolist()

# '사고형태' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
form_levels = edu2023['사고형태'].value_counts()
form_labels = form_levels.index.tolist()
form_values = form_levels.values.tolist()


# 서브플롯 생성 (1행 3열의 레이아웃)
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])

# 첫 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=spot_labels, values=spot_values, hole=.3, title="사고장소"), 1, 1)

# 두 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=part_labels, values=part_values, hole=.3, title="사고부위"), 1, 2)

# 세 번째 파이 차트 추가
fig.add_trace(go.Pie(labels=form_labels, values=form_values, hole=.3, title="사고형태"), 1, 3)

# 레이아웃 업데이트
fig.update_layout(title_text="사고관련 정보")

# 차트 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# '사고매개물' 열의 각 카테고리 빈도 계산/카테고리와 빈도를 각각 labels와 values로 추출
me_levels = edu2023['매개물'].value_counts()
me_labels = me_levels.index.tolist()
me_values = me_levels.values.tolist()

data = {
    '사고매개물': me_labels,
    'count': me_values
}
df = pd.DataFrame(data)

df = df.sort_values(by='count', ascending=False).head(10)

fig = px.bar(df, x="사고매개물", y="count", title="사고관련 매개물")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **교육부 학교안전교육 전문강사 인력풀 현황**

# %%
pro_edu.head()
# Out:
#    시도  생활안전  교통안전  폭력예방_신변보호  약물_사이버중독예방  재난안전  직업안전  응급처치   합계
# 0  서울    23     3         33          11    21     1    21  113
# 1  부산    10     1         14          10     4     1    10   50
# 2  대구    10     5         11           1     5     2    15   49
# 3  인천     8     3         12           2     5     6     8   44
# 4  광주     4     0         25           4     4     0     2   39

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=pro_edu['시도'],
                     y=pro_edu['생활안전'],
                     name='생활안전',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=pro_edu['시도'],
                     y=pro_edu['교통안전'],
                     name='교통안전',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=pro_edu['시도'],
                     y=pro_edu['폭력예방_신변보호'],
                     name='폭력예방_신변보호',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=pro_edu['시도'],
                     y=pro_edu['약물_사이버중독예방'],
                     name='약물_사이버중독예방',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=pro_edu['시도'],
                     y=pro_edu['재난안전'],
                     name='재난안전',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=pro_edu['시도'],
                     y=pro_edu['직업안전'],
                     name='직업안전',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=pro_edu['시도'],
                     y=pro_edu['응급처치'],
                     name='응급처치',
                     marker_color='rgb(250, 251, 252)'
                     ))

fig.update_layout(
    title='시도별 학교안전교육 전문강사 인력풀 현황',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **학교생활별 안전사고 현황 데이터**

# %%
school_part.head(1)
# Out:
#      연도 학교급별    얼굴 가슴_등_허리  머리(두부)  치아(구강) 흉복부    팔  손   다리  발   기타    합계
# 0  2009    유  1820      77     327     379   0  817  0  466  0  208  4094

# %%
# 미집계를 '0'으로 변환
school_part = school_part.replace('미집계', 0)
school_part.head(1)
# Out:
#      연도 학교급별    얼굴 가슴_등_허리  머리(두부)  치아(구강) 흉복부    팔  손   다리  발   기타    합계
# 0  2009    유  1820      77     327     379   0  817  0  466  0  208  4094

# %%
school_part = school_part.astype({'얼굴':'int', '가슴_등_허리':'int', '흉복부':'int', '손':'int', '발':'int'})
school_part.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   연도       84 non-null     int64
#  1   학교급별     84 non-null     object
#  2   얼굴       84 non-null     int64
#  3   가슴_등_허리  84 non-null     int64
#  4   머리(두부)   84 non-null     int64
#  5   치아(구강)   84 non-null     int64
#  6   흉복부      84 non-null     int64
#  7   팔        84 non-null     int64
#  8   손        84 non-null     int64
#  9   다리       84 non-null     int64
#  10  발        84 non-null     int64
#  11  기타       84 non-null     int64
#  12  합계       84 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 8.7+ KB

# %%
school_part_2009 = school_part[school_part['연도']==2009]
school_part_2010 = school_part[school_part['연도']==2010]
school_part_2011 = school_part[school_part['연도']==2011]
school_part_2012 = school_part[school_part['연도']==2012]
school_part_2013 = school_part[school_part['연도']==2013]
school_part_2014 = school_part[school_part['연도']==2014]
school_part_2015 = school_part[school_part['연도']==2015]
school_part_2016 = school_part[school_part['연도']==2016]
school_part_2017 = school_part[school_part['연도']==2017]
school_part_2018 = school_part[school_part['연도']==2018]
school_part_2019 = school_part[school_part['연도']==2019]
school_part_2020 = school_part[school_part['연도']==2020]
school_part_2021 = school_part[school_part['연도']==2021]

# %% [markdown]
# #####1. 2009 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2009['학교급별'],
                     y=school_part_2009['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2009년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####2. 2010 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2010['학교급별'],
                     y=school_part_2010['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2010년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####3. 2011 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2011['학교급별'],
                     y=school_part_2011['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2011년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####4. 2012 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2012['학교급별'],
                     y=school_part_2012['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2012년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####5. 2013 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2013['학교급별'],
                     y=school_part_2013['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2013년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####6. 2014 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2014['학교급별'],
                     y=school_part_2014['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2014년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####7. 2015 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2015['학교급별'],
                     y=school_part_2015['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2015년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####8. 2016 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2016['학교급별'],
                     y=school_part_2016['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2016년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####9. 2017 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2017['학교급별'],
                     y=school_part_2017['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2017년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####10. 2018 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2018['학교급별'],
                     y=school_part_2018['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2018년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####11. 2019 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2019['학교급별'],
                     y=school_part_2019['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2019년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####12. 2020 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2020['학교급별'],
                     y=school_part_2020['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2020년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #####13. 2021 학교생활별 안전사고 현황 데이터(https://m.blog.naver.com/shapesoflife/222448780326)

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['얼굴'],
                     name='얼굴',
                     marker_color='rgb(6, 80, 191)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['가슴_등_허리'],
                     name='가슴_등_허리',
                     marker_color='rgb(26, 118, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['머리(두부)'],
                     name='머리(두부)',
                     marker_color='rgb(92, 157, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['치아(구강)'],
                     name='치아(구강)',
                     marker_color='rgb(143, 188, 255)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['흉복부'],
                     name='흉복부',
                     marker_color='rgb(167, 169, 171)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['팔'],
                     name='팔',
                     marker_color='rgb(165, 181, 204)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['손'],
                     name='손',
                     marker_color='rgb(122, 139, 163)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['다리'],
                     name='다리',
                     marker_color='rgb(82, 102, 130)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['발'],
                     name='발',
                     marker_color='rgb(150, 157, 168)'
                     ))
fig.add_trace(go.Bar(x=school_part_2021['학교급별'],
                     y=school_part_2021['기타'],
                     name='기타',
                     marker_color='rgb(250, 251, 252)'
                     ))


fig.update_layout(
    title='2021년 학교생활별 안전사고 현황 데이터',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='전문강사수',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
